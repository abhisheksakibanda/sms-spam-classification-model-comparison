# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import string
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec
from collections import Counter
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# Read SMS Dataset
sms_spam = pd.read_csv('spam.csv', encoding='latin-1', usecols=[0, 1])
sms_spam.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)
sms_spam.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Text preprocessing
corpus = []
for i in range(0, len(sms_spam)):
    # Remove non-alphabetic characters, convert to lowercase, and split into words
    review = re.sub('[^a-zA-Z]', ' ', sms_spam['text'][i])
    review = review.lower()
    review = review.split()

    # Apply stemming and remove stopwords
    ps = PorterStemmer()
    nltk.download('stopwords')
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
# Create a CountVectorizer and transform the corpus into a bag-of-words representation
cv = CountVectorizer()
X = cv.fit_transform(corpus).toarray()
y = sms_spam.iloc[:, 0].values

# %%
# Display some information about the processed data
print(cv.get_feature_names_out()[0:20])
print(cv.get_feature_names_out()[-20:])
# Out:
# ['aa' 'aah' 'aaniy' 'aaooooright' 'aathi' 'ab' 'abbey' 'abdomen' 'abeg'
#  'abel' 'aberdeen' 'abi' 'abil' 'abiola' 'abj' 'abl' 'abnorm' 'abouta'
#  'abroad' 'absenc']
# ['yunni' 'yuo' 'yuou' 'yup' 'yupz' 'zac' 'zaher' 'zealand' 'zebra' 'zed'
#  'zero' 'zf' 'zhong' 'zindgi' 'zoe' 'zogtoriu' 'zoom' 'zouk' 'zs' 'zyada']

# %%
# Features Count
print(X.shape)
print(y.shape)
# Out:
# (5572, 6221)
# (5572,)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (4457, 6221)
# (1115, 6221)

# %%
# Extract words from spam and ham messages
ham_words = ''
spam_words = ''
spam = sms_spam[sms_spam.label == 'spam']
ham = sms_spam[sms_spam.label == 'ham']

# %%
# Process spam messages
for val in spam.text:
    text = re.sub('[^a-zA-Z]', ' ', val)
    text = text.lower()
    text = text.split()
    ps = PorterStemmer()
    text = [ps.stem(word) for word in text if not word in set(stopwords.words('english'))]
    for words in text:
        spam_words = spam_words + words + ' '

# Process ham messages
for val in ham.text:
    text = re.sub('[^a-zA-Z]', ' ', val)
    text = text.lower()
    text = text.split()
    ps = PorterStemmer()
    text = [ps.stem(word) for word in text if not word in set(stopwords.words('english'))]
    for words in text:
          ham_words = ham_words + words + ' '

# %%
# Define a function for text processing
def text_process(text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    STOPWORDS = stopwords.words('english') + ['u', 'ü', 'ur', '4', '2', 'im', 'dont', 'doin', 'ure']
    # Check characters to see if they are in punctuation
    nopunc = [char for char in text if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return ' '.join([word for word in nopunc.split() if word.lower() not in STOPWORDS])

# %%
# Apply text processing to create a new 'clean_text' column in the dataset
sms_spam['clean_text'] = sms_spam.text.apply(text_process)
sms_spam.head()
sms_spam['clean_text'].fillna("unknown", inplace=True)

# %%
# Analyze the most common words in ham messages
words = sms_spam[sms_spam.label=='ham'].clean_text.apply(lambda x: [word.lower() for word in x.split()])
ham_words = Counter()

for msg in words:
    ham_words.update(msg)
    
ham_words.most_common(50)
# Out:
# [('get', 303),
#  ('ltgt', 276),
#  ('ok', 272),
#  ('go', 247),
#  ('ill', 236),
#  ('know', 232),
#  ('got', 231),
#  ('like', 229),
#  ('call', 229),
#  ('come', 224),
#  ('good', 222),
#  ('time', 189),
#  ('day', 187),
#  ('love', 185),
#  ('going', 167),
#  ('want', 163),
#  ('one', 162),
#  ('home', 160),
#  ('lor', 160),
#  ('need', 156),
#  ('sorry', 153),
#  ('still', 146),
#  ('see', 137),
#  ('n', 134),
#  ('later', 134),
#  ('da', 131),
#  ('r', 131),
#  ('back', 129),
#  ('think', 128),
#  ('well', 126),
#  ('today', 125),
#  ('send', 123),
#  ('tell', 121),
#  ('cant', 118),
#  ('ì', 117),
#  ('hi', 117),
#  ('take', 112),
#  ('much', 112),
#  ('oh', 111),
#  ('night', 107),
#  ('hey', 106),
#  ('happy', 105),
#  ('great', 100),
#  ('way', 100),
#  ('hope', 99),
#  ('pls', 98),
#  ('work', 96),
#  ('wat', 95),
#  ('thats', 94),
#  ('dear', 94)]

# %%
# # Analyze the most common words in spam messages
words = sms_spam[sms_spam.label=='spam'].clean_text.apply(lambda x: [word.lower() for word in x.split()])
spam_words = Counter()

for msg in words:
    spam_words.update(msg)
    
spam_words.most_common(50)
# Out:
# [('call', 347),
#  ('free', 216),
#  ('txt', 150),
#  ('mobile', 123),
#  ('text', 120),
#  ('claim', 113),
#  ('stop', 113),
#  ('reply', 101),
#  ('prize', 92),
#  ('get', 83),
#  ('new', 69),
#  ('send', 67),
#  ('nokia', 65),
#  ('urgent', 63),
#  ('cash', 62),
#  ('win', 60),
#  ('contact', 56),
#  ('service', 55),
#  ('please', 52),
#  ('guaranteed', 50),
#  ('customer', 49),
#  ('16', 49),
#  ('week', 49),
#  ('tone', 48),
#  ('per', 46),
#  ('phone', 45),
#  ('18', 43),
#  ('chat', 42),
#  ('awarded', 38),
#  ('draw', 38),
#  ('latest', 36),
#  ('å£1000', 35),
#  ('line', 35),
#  ('150ppm', 34),
#  ('mins', 34),
#  ('receive', 33),
#  ('camera', 33),
#  ('1', 33),
#  ('every', 33),
#  ('message', 32),
#  ('holiday', 32),
#  ('landline', 32),
#  ('shows', 31),
#  ('å£2000', 31),
#  ('go', 31),
#  ('box', 30),
#  ('number', 30),
#  ('apply', 29),
#  ('code', 29),
#  ('live', 29)]

# %%
sms_spam
# Out:
#      label                                               text  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                              clean_text
# 0     Go jurong point crazy Available bugis n great ...
# 1                                 Ok lar Joking wif oni
# ...

# %%
X = sms_spam['clean_text']
Y = sms_spam['label']

# %%
# Vectorize the text data using CountVectorizer with specific settings
vect = CountVectorizer(min_df=5, ngram_range=(1,2)).fit(X)

X_vec = vect.transform(X)
# Display information about the vectorized data
len(vect.get_feature_names_out())
# Out:
# 2256

# %%
# Split the vectorized data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state = 0)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4457, 2256)
# (1115, 2256)
# (4457,)
# (1115,)

# %%
# Logistic Regression
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression

# Create a pipeline for the Logistic Regression model
model_lr = Pipeline([('tfidf', TfidfTransformer()),
                   ('model', LogisticRegression()),
                   ])

# Train the Logistic Regression model
model_lr.fit(X_train, y_train)

# Predict on the test set
ytest = np.array(y_test)
pred_y = model_lr.predict(X_test)

# %%
# Plot Confusion Matrix
conf_matrix_lr = confusion_matrix(y_test, pred_y)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_lr, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# Evaluate Logistic Regression model performance
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

print('accuracy: %s' %accuracy_score(pred_y, y_test))
print(classification_report(ytest, pred_y))
# Out:
# accuracy: 0.9641255605381166
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       949
#         spam       0.99      0.77      0.86       166
#
#     accuracy                           0.96      1115
#    macro avg       0.98      0.88      0.92      1115
# weighted avg       0.97      0.96      0.96      1115

# %%
# Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB

# Create pipeline
model_nb = Pipeline([('tfidf', TfidfTransformer()),
                   ('model', MultinomialNB()),
                   ])

#Train Model
model_nb.fit(X_train, y_train)

# Predict on test set
ytest = np.array(y_test)
pred = model_nb.predict(X_test)

# %%
# Plot Confusion Matrix
conf_matrix_nb = confusion_matrix(y_test, pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_nb, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# Evaluate model performance
print('accuracy %s' %accuracy_score(pred, y_test))
print(classification_report(ytest, pred))
# Out:
# accuracy 0.9704035874439462
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98       949
#         spam       1.00      0.80      0.89       166
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.90      0.94      1115
# weighted avg       0.97      0.97      0.97      1115

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# Create pipeline
model_rf = Pipeline([('tfidf', TfidfTransformer()),
                   ('model',RandomForestClassifier(n_estimators=50)),
                   ])

# Train Model
model_rf.fit(X_train, y_train)

# Predict on test set
ytest = np.array(y_test)
preds = model_rf.predict(X_test)

# Evaluate model performance
print('accuracy %s' %accuracy_score(preds, y_test))
print(classification_report(ytest, preds))
# Out:
# accuracy 0.9721973094170404
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98       949
#         spam       1.00      0.81      0.90       166
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.91      0.94      1115
# weighted avg       0.97      0.97      0.97      1115

# %%
# Plot Confusion Matrix
conf_matrix_rf = confusion_matrix(y_test, preds)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_rf, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# Stochastic Gradient Descent
from sklearn.linear_model import SGDClassifier

# Create pipeline
model_sg = Pipeline([('tfidf', TfidfTransformer()),
                     ('model',SGDClassifier()),
                     ])

# Train Model
model_sg.fit(X_train, y_train)

# Predict on test set
ytest = np.array(y_test)
predicted = model_sg.predict(X_test)

# Evaluate model performance
print('accuracy %s' %accuracy_score(predicted, y_test))
print(classification_report(ytest, predicted))
# Out:
# accuracy 0.9829596412556054
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       949
#         spam       0.99      0.89      0.94       166
#
#     accuracy                           0.98      1115
#    macro avg       0.99      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
# Plot Confusion Matrix
conf_matrix_sgd = confusion_matrix(y_test, predicted)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_sgd, annot=True, fmt='d', cmap='Blues')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
